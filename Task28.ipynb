# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Summary of Data

# %% [markdown]
# - Data contains record of audiobooks from 1998 till 2025. Audiobooks of 2025 not released yet. Data has 8 columns containing information of different audiobook in each row. Information include Name of book its writer, narrator, time of audio book recording, release date, language of book content, rating to book with stars & price of book. Our goal is to make dataset which will provide information related to great book data has 87489 rows and 8 columns

# %% [markdown]
# ### Column Breakdown
# - name: Name of the audiobook
# - author: Author of the audiobook
# - narrator: Narrator of the audiobook
# - time: Length of the audiobook
# - releasedate: Release date of the audiobook
# - language: Language of the audiobook
# - stars: No. of stars the audiobook received
# - price: Price of the audiobook in INR
# - ratings: No. of reviews received by the audiobook

# %% [markdown]
# # Issues with Dataset
#
# ### Dirty data issues (completeness,validity,accuracy,consistency)
#
# #### name,author,narrator column
# - name,author,narrator columns has encoding character issue, some characters are not encoded properly (while reading in pandas this issue handled UTF-8 encoding) (validity) &#10003;
# - name,author,narrator columns contains different language data (consistency) &#10003;
# - in author & narrator column first name and last name not seperated by white space(validity)
# - No need of Writtenby: in author column (validity) &#10003;
# - No need of Narratedby in narrator column (validity) &#10003;
# - row 35 in names column book name contains book categories (14 Short Stories Bundle for Kids: Adventure, Science Fiction, Aesopâ€™s Fables, Classic Fairy Tales and Christmas Story Books for Children)(validity)
# - There are no proper names in narrator, e.g., "Narratedby:uncredited".(accuracy)
#
# #### releasedate
# - need datatype change in releasedate column(validity) &#10003;
#
# #### language
# - in laguage some values are in title format and some in lowercase(consistency) &#10003;
# - need datatype change in laguage column to category(validity) &#10003;
#
# #### stars
# - Some empty values are represented as "Not rated yet" in stars column. For that, we can assume total ratings = 0 and avg. ratings = 0.(completeness) &#10003;
#
# #### price
# - price columns some values in float and some in int need dtype change(consistency) &#10003;
# - Free mentioned in price replace with 0(completeness)  &#10003;
#
# #### Suggestion
# - if data has genre column it will help in book categorization &#128161;
#
# ### Messy data issues (Untidy data-Structural issue)
#
# #### name,author,narrator column
# - name columns contains 2 info combined book name and its edition
# - books written by multiple people Writtenby:EdwardWyke-Smith,VeronicaCossanteli comma seperated data
# - books Narrated by multiple people comma seperated data
#
# #### time
# - in time column hrs and min in single column seperated by and need single column in minutes convert into int dtype &#10003;
#
# #### stars
# - stars has ratings and reviews in same columns need seperate column also rating is out of 5 no need to mention &#10003;

# %%
# with chunksize we are reading only first 1000 lines
audio = pd.read_csv(r"D:\Jupyter\audible_uncleaned(in).csv",chunksize=1000)
for i in audio:
    df1 = i.copy()
    break

# %%
# check for data structure with first 5 values 
df1.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins  08-04-2008  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins  05-01-2018  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins  11-06-2020  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins  10-05-2021  English
# 4  Narratedby:JesseBernstein              10 hrs  13-01-2010  English
#
#                            stars price
# 0     5 out of 5 stars34 ratings   468
# 1   4.5 out of 5 stars41 ratings   820
# 2   4.5 out of 5 stars38 ratings   410
# 3   4.5 out of 5 stars12 ratings   615
# 4  4.5 out of 5 stars181 ratings   820

# %%
# check for data structure with last 5 values
df1.tail()
# Out:
#                                                   name  \
# 995  Battle for Loot Lake: An Unofficial Fortnite A...
# 996                          Midnight for Charlie Bone
# 997                                    Winnie-the-Pooh
# 998                               Midnight on the Moon
# 999                                      Erak's Ransom
#
#                         author                      narrator  \
# 995      Writtenby:DevinHunter      Narratedby:RamondeOcampo
# 996       Writtenby:JennyNimmo  Narratedby:SimonRussellBeale
# 997        Writtenby:A.A.Milne        Narratedby:AlanBennett
# 998  Writtenby:MaryPopeOsborne    Narratedby:MaryPopeOsborne
# 999     Writtenby:JohnFlanagan       Narratedby:WilliamZappa
#
#                   time releasedate language                      stars price
# 995   2 hrs and 7 mins    18-09-18  English  5 out of 5 stars2 ratings   585
# 996   7 hrs and 9 mins    18-12-15  English              Not rated yet   569
# 997    1 hr and 5 mins    27-01-09  English              Not rated yet   342
# 998            49 mins    13-12-06  English              Not rated yet   301
# 999  12 hrs and 3 mins  04-06-2012  English              Not rated yet   702

# %%
# check for data structure with random 5 values
df1.sample(5)
# Out:
#                                             name  \
# 583                     Thursdays with the Crown
# 369          PJ Masks - Vet aquí els Mini Llops!
# 462  Ivy & Bean Break the Fossil Record (Book 3)
# 967                                 Black Beauty
# 452                        ¡Sálvese quien pueda!
#
#                                author                   narrator  \
# 583        Writtenby:JessicaDayGeorge    Narratedby:GraceAndrews
# 369  Writtenby:eOne,AnaC.AlcainaPerez  Narratedby:RogerSerradell
# 462            Writtenby:AnnieBarrows   Narratedby:HallieRicardo
# 967              Writtenby:AnnaSewell     Narratedby:RalphCosham
# 452       Writtenby:JordiSierraiFabra  Narratedby:AnetaFernández
#
#                   time releasedate language                     stars price
# 583  5 hrs and 38 mins  10-08-2021  English             Not rated yet   600
# 369            11 mins  01-07-2022  catalan             Not rated yet    38
# 462    1 hr and 8 mins  01-04-2022  English             Not rated yet   500
# 967  5 hrs and 21 mins    22-12-11  English  4 out of 5 stars1 rating   668
# 452  2 hrs and 47 mins  12-01-2021  spanish             Not rated yet   192

# %%
# checking general information about data no of rows,columns,non-null values,memory usage,dtype
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   author       1000 non-null   object
#  2   narrator     1000 non-null   object
#  3   time         1000 non-null   object
#  4   releasedate  1000 non-null   object
#  5   language     1000 non-null   object
#  6   stars        1000 non-null   object
#  7   price        1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %% [markdown]
# #### Working on price column
# #### Define
# - Replacing Free with "0" when we use replace on string str.replace() only work on string and for int & float it return nan
# - Change dtype to np.float32 for memory optimization

# %%
# checking unique values in price if any other values than Free 
df1["price"].unique()
# Out:
# array(['468', '820', '410', '615', '656', '233', '1,256.00', '1,206.00',
#        '1,093.00', '467', '836', '1,003.00', '957', '683', '469', '374',
#        '702', '501', '284', '575', '668', '305', '1,170.00', '266',
#        '1,005.00', '323', '516', '445', '585', '703', '117', '192', '76',
#        '821', '200', '706', '904', '679', '112', '531', '586', '1,172.00',
#        '949', '322', '569', '398', '352', '164', '234', '303', '32',
#        '166', '38', '75', '799', '664', '204', '568', '186', '797', '99',
#        '65', '300', '113', '493', '573', '759', '367', '338', '1,382.00',
#        '105', '422', '754', '492', '529', '189', '258', '609', '1,328.00',
#        '187', '726', '645', '151', '115', '149', '263', '307', '116',
#        '225', '959', '452', '36', '265', '653', '515', '227', '351',
#        '500', '333', '301', '93', '397', '502', '267', '384', '268',
#        '153', '733', '434', '228', '600', '535', '968', '854', '132',
#        '334', '401', '866', '402', '420', '417', '190', '251', '335',
#        '379', '719', '490', '47', '478', '626', '873', '281', '100',
#        '903', '721', '240', '378', '82', '191', '230', '140', '389',
#        '376', '441', '933', '537', '756', '888', '752', '512', '930',
#        '201', '197', '1,063.00', '691', '1,008.00', 'Free', '342'],
#       dtype=object)

# %%
# Checking rows containing price as 'Free'
df1[df1["price"] == "Free"]
# Out:
#                  name               author                   narrator  \
# 983  Ringo & the Yogi  Writtenby:PrasunRoy  Narratedby:SiddhantaPinto
#
#                   time releasedate language                      stars price
# 983  5 hrs and 18 mins    19-11-19  English  4 out of 5 stars4 ratings  Free

# %%
# why replaced with "0" when we use replace on string str.replace() only work on string and for int & float it return nan 
df1["price"] = df1["price"].replace("Free","0")

# %%
#Change dtype to np.float32 for memory optimization
df1["price"] = df1["price"].str.replace(",","").astype(np.float32)

# %%
#check if any missing value added in data
df1[df1["price"].isna()]
# Out:
# Empty DataFrame
# Columns: [name, author, narrator, time, releasedate, language, stars, price]
# Index: []

# %% [markdown]
# #### Working on stars column
# #### Define
# - function creation to seperate start_rating and rating and new columns added in dataframe
# - drop of stars column after two seperate columns for start_rating and rating created
# - datatype changed of start_rating column to np.float32 for memory optimization

# %%
def star_rating(text):
    try:
        return float(re.split("\s",text)[0])
    except:
        return 0

def rating(text):
    try:
        return int(re.split("\s",text)[4].replace("stars",""))
    except:
        return 0

# %%
df1["star_rating"] = df1["stars"].apply(star_rating)
df1["rating"] = df1["stars"].apply(rating)

# %%
df1.drop(columns="stars",inplace=True)

# %%
df1["star_rating"] = df1["star_rating"].astype(np.float32)

# %% [markdown]
# #### Working on language column
# #### Define
# - changing all languages to lower case to create consistency in data format
# - datatype changed of language column to category for memory optimization

# %%
df1["language"] = df1["language"].str.lower().astype("category")

# %% [markdown]
# #### Working on releasedate column
# #### Define
# - datatype changed of releasedate column to datetime64[ns] for effective utilization

# %%
df1["releasedate"] = pd.to_datetime(df1["releasedate"])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9864\2862309026.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df1["releasedate"] = pd.to_datetime(df1["releasedate"])

# %%
#checking ammended details 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   author       1000 non-null   object
#  2   narrator     1000 non-null   object
#  3   time         1000 non-null   object
#  4   releasedate  1000 non-null   datetime64[ns]
#  5   language     1000 non-null   category
#  6   price        1000 non-null   float32
#  7   star_rating  1000 non-null   float32
#  8   rating       1000 non-null   int64
# dtypes: category(1), datetime64[ns](1), float32(2), int64(1), object(4)
# memory usage: 56.5+ KB

# %% [markdown]
# #### Working on time column
# #### Define
# - function creation using regex to change hrs and min into munites

# %%
def to_min(text):
    pattern = r"(?:(\d+)\s*hrs?)?\s*(?:and)?\s*(?:(\d+)\s*mins?)?"
    match = re.search(pattern, text)
    if match:
        hours = match.group(1) if match.group(1) else "0"
        minutes = match.group(2) if match.group(2) else "0"
        min1 = int(hours)*60 + int(minutes)
        return min1

# %%
df1["time"] = df1["time"].apply(to_min)

# %% [markdown]
# #### Working on narrator,author,name columns
# #### Define
# - checking all values in narrator startswith Narratedby: and author with Writtenby: if yes
# - replace values with "" null string and change in original data
# - random check on whole data found different language
# - function creation to translate data in narrator,author,name

# %%
print(df1["narrator"].str.startswith("Narratedby:").sum())
print(df1["author"].str.startswith("Writtenby:").sum())
# Out:
# 1000
# 1000

# %%
df1["narrator"] = df1["narrator"].str.replace("Narratedby:","")
df1["author"] = df1["author"].str.replace("Writtenby:","")

# %%
#random check on whole data found different language
pd.read_csv(r"D:\Jupyter\audible_uncleaned(in).csv")["narrator"][87192]
# Out:
# 'Narratedby:小野田英一'

# %%
# from deep_translator import GoogleTranslator

# # Translate function
# def translate_name(name):
#     try:
#         return GoogleTranslator(source="auto", target="en").translate(name)
#     except:
#         return name  # Return original if translation fails

# %%
#df1["name"] = df1["name"].apply(translate_name)

# %%
#df1["author"] = df1["author"].apply(translate_name)

# %%
#df1["narrator"] = df1["narrator"].apply(translate_name)

# %%
df1.to_csv("cleaned_audio.csv",index=False)

# %%
#i["author"].unique()[20:30]
# Out:
# array(['Writtenby:DavPilkey', 'Writtenby:DustiBowling',
#        'Writtenby:JulieSykes', 'Writtenby:StellaRobson',
#        'Writtenby:JudeWatson', 'Writtenby:FranciscoDíazValladares',
#        'Writtenby:Mattel', 'Writtenby:Vegetta777,Willyrex',
#        'Writtenby:RoshaniChokshi',
#        'Writtenby:SophieSchoenwald,NadineReitz-Illustrator'], dtype=object)

# %%
#df1["author"].unique()[20:30]
# Out:
# array(['DavPilkey', 'DustiBowling', 'Juliesykes', 'StellaRobson',
#        'JudeWatson', 'FRANCISCODÍZVALADARES', 'Mattel',
#        'Vegetta777,Willyrex', 'Roshanichokshi',
#        'SophieSchoenwald,NadineReitz-Illustrator'], dtype=object)

# %%
# Some details change found after translating the data

# %% [markdown]
# ##### ShannonMessenger > Shannonmesser, DanGutman > Dangutman , RuskinBond > Intodring , JuliaDonaldson > Juladonaldson,
# ##### AxelScheffler> Axelscheffler , JulieSykes > Juliesykes ,

# %%
df1["author"].unique()[:10]
# Out:
# array(['GeronimoStilton', 'RickRiordan', 'JeffKinney', 'SuzanneCollins',
#        'WinterMorgan', 'MaryPopeOsborne', 'PhilipPullman',
#        'Shannonmesser', 'ChristopherPaolini', 'Eoincolfer'], dtype=object)

# %%
# so decide to skip translation step

# %%
df1
# Out:
#                                                   name           author  \
# 0                           Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                     The Burning Maze      RickRiordan
# 2                                         The Deep End       JeffKinney
# 3                                 Daughter of the Deep      RickRiordan
# 4           The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ..                                                 ...              ...
# 995  Battle for Loot Lake: An Unofficial Fortnite A...      DevinHunter
# 996                          Midnight for Charlie Bone       JennyNimmo
# 997                                    Winnie-the-Pooh        A.A.Milne
# 998                               Midnight on the Moon  MaryPopeOsborne
# 999                                      Erak's Ransom     JohnFlanagan
#
#               narrator  time releasedate language  price  star_rating  rating
# 0           BillLobely   140  2008-08-04  english  468.0          5.0      34
# 1        RobbieDaymond   788  2018-05-01  english  820.0          4.5      41
# 2           DanRussell   123  2020-11-06  english  410.0          4.5      38
# 3       SoneelaNankani   676  2021-10-05  english  615.0          4.5      12
# 4       JesseBernstein   600  2010-01-13  english  820.0          4.5     181
# ..                 ...   ...         ...      ...    ...          ...     ...
# 995      RamondeOcampo   127  2018-09-18  english  585.0          5.0       2
# 996  SimonRussellBeale   429  2015-12-18  english  569.0          0.0       0
# 997        AlanBennett    65  2009-01-27  english  342.0          0.0       0
# 998    MaryPopeOsborne    49  2006-12-13  english  301.0          0.0       0
# 999       WilliamZappa   723  2012-04-06  english  702.0          0.0       0
#
# [1000 rows x 9 columns]

# %%
in author & narrator column first name and last name not seperated by white space(validity)
row 35 in names column book name contains book categories (14 Short Stories Bundle for Kids: Adventure, Science Fiction, Aesopâ€™s Fables, Classic Fairy Tales and Christmas Story Books for Children)(validity)
There are no proper names in narrator, e.g., "Narratedby:uncredited".(accuracy)
name columns contains 2 info combined book name and its edition
books written by multiple people Writtenby:EdwardWyke-Smith,VeronicaCossanteli comma seperated data
books Narrated by multiple people comma seperated data

# %%
df1["name"].sample(10)
# Out:
# 127                             The Hidden Kingdom
# 391           Avengers - TRE spektakulära äventyr!
# 793                     Le vaillant petit tailleur
# 230    I Survived the Sinking of the Titanic, 1912
# 838                          Ein gefährlicher Pakt
# 686                        Ein rätselhafter Unfall
# 16                     Magic Tree House Collection
# 814                          A Thunder of Monsters
# 667                               Noticias frescas
# 864                                The Stolen Show
# Name: name, dtype: object

# %%
# Now, remove the starnge parts from the "name", "author" and "narrator" columns
df1["name"]     = df1["name"].str.encode('ascii', 'ignore').str.decode('ascii').copy()
df1["author"]   = df1["author"].str.encode('ascii', 'ignore').str.decode('ascii').copy()
df1["narrator"] = df1["narrator"].str.encode('ascii', 'ignore').str.decode('ascii').copy()

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   author       1000 non-null   object
#  2   narrator     1000 non-null   object
#  3   time         1000 non-null   int64
#  4   releasedate  1000 non-null   datetime64[ns]
#  5   language     1000 non-null   category
#  6   price        1000 non-null   float32
#  7   star_rating  1000 non-null   float32
#  8   rating       1000 non-null   int64
# dtypes: category(1), datetime64[ns](1), float32(2), int64(2), object(3)
# memory usage: 56.5+ KB

# %%
df1["name"].unique()
# Out:
# array(['Geronimo Stilton #11 & #12', 'The Burning Maze', 'The Deep End',
#        'Daughter of the Deep',
#        'The Lightning Thief: Percy Jackson, Book 1',
#        'The Hunger Games: Special Edition', 'Quest for the Diamond Sword',
#        'The Dark Prophecy', 'Merlin Mission Collection',
#        'The Tyrants Tomb', "The Titan's Curse: Percy Jackson, Book 3",
#        'Magic Tree House Collection: Books 9-16',
#        'Magic Tree House Collection: Books 1-8',
#        'Magnus Chase and the Ship of the Dead', 'Northern Lights',
#        'Geronimo Stilton #13 and #14', 'Magic Tree House Collection',
#        'Exile', 'Neverseen', 'The Tower of Nero',
#        'Eldest: The Inheritance Cycle, Book 2', 'Artemis Fowl',
#        'Geronimo Stilton 22 & 24',
#        'Percy Jackson and the Battle of the Labyrinth', 'Winnie-the-Pooh',
#        'Magic Tree House Collection: Books 25-32',
#        'Geronimo Stilton #20 and #21', 'The Red Pyramid',
#        "Mystery of the Griefer's Mark", 'Geronimo Stilton #17',
#        'The House at Pooh Corner', 'Mission Unstoppable',
#        'Darkness of Dragons',
#        '14 Short Stories Bundle for Kids: Adventure, Science Fiction, Aesops Fables, Classic Fairy Tales and Christmas Story Books for Children',
#        'The Adventures of Rusty', 'Geronimo Stilton #15 and #16',
#        'The Lost Heir', 'Everblaze', 'Treasure Hunters in Trouble',
#        'Lodestar', 'Curse of the Arctic Star',
#        'The Ghost of Grey Fox Inn',
#        "Rowley Jefferson's Awesome Friendly Adventure", 'Flashback',
#        'Secret of the Red Arrow', 'Clash of the Creepers',
#        'The Skeletons Strike Back', 'Dragonslayer',
#        'A Bear Called Paddington',
#        'Gregor and the Curse of the Warmbloods', 'The Dark Secret',
#        "The Gruffalo's Child", 'Keys to the Demon Prison', 'Legacy',
#        'The Endermen Invasion',
#        'Captain Underpants and the Revolting Revenge of the Radioactive Robo-Boxers',
#        'You Only Die Twice', 'From Texas with Love', 'Across the Desert',
#        'Unicorn Academy: Aisha and Silver',
#        'Laura Blackman and The Five Cunning Aardvarks',
#        'The Dragonet Prophecy', 'Dangerous Gift', 'The 39 Clues, Book 6',
#        'Never Say Genius', 'The Madman of Black Bear Mountain',
#        'Unicorn Academy: Zara and Moonbeam', 'El fantasma de la bodega',
#        'El paseo encantado', 'Wigetta',
#        'Aru Shah and the Nectar of Immortality',
#        'Barnabas der Wolkenschaufler', 'The Boy in the Post', 'Thornwood',
#        "7 histoires d'aventures !",
#        'Le Loup qui devenait chef de la fort', 'Curse of the Robo-Dragon',
#        'Call of the Crow', 'Glass Slippers',
#        'Captain Underpants and the Sensational Saga of Sir Stinks-a-Lot',
#        'Tiger Honor', 'The Amulet of Samarkand',
#        "Rowley Jefferson's Awesome Friendly Spooky Stories",
#        'Lost in the End', 'Trouble Island', 'Terrors of the Forest',
#        'Riverboat Roulette', 'The Book of Chaos',
#        'Fortunately, the Milk...', 'Discoveries in the Overworld',
#        'The Last Human', 'Welcome to Smellville',
#        "An Explorer's Guide to the Nether", 'The Midnight Gang',
#        'As the Falcon Flies',
#        'The Squad of Lucky Landing: An Unofficial Fortnite Adventure Novel',
#        'Pahua and the Soul Stealer', 'El monstruo marino secreto',
#        'Sabotage on the Solar Express', 'A Boy Called Christmas',
#        'The 39 Clues, Book 4', 'The 39 Clues, Book 3',
#        'The Disappearance', 'Once Upon a Crime', 'Billionaire Boy',
#        'The Blue Lady of Coffin Hall', "Danger at Dead Man's Pass",
#        'Unlocked', 'The Danger Gang', 'Mountain Mare',
#        'The Princess in Black and the Mermaid Princess',
#        'The Vanishing Statue', 'Eye of the Earthquake Dragon',
#        'Peril at Granite Peak', 'Barbie - Aventura espacial',
#        'The Disappearance of Emily Downs', 'The Solution',
#        'The Great Greenfield Bake-Off', 'Into Thin Air',
#        'Once upon a Thriller', "The Magician's Nephew",
#        'Leonora Bolt: Secret Inventor', 'The Snail and the Whale',
#        'Tigers for Dinner', 'The Hidden Kingdom', 'Eagle Strike',
#        'Captain Marvel - Ultron blir viral', 'Toy Story 4',
#        'Three Lost Seeds', 'Mystery on the Mayhem Express',
#        'Tunnel of Secrets', 'Barbie - La puerta secreta',
#        'A scuola con Pongo e Tim: Henry Every',
#        'Black Panther: Spellbound', 'The 39 Clues: Unstoppable, Book 3',
#        'Hello Kitty - El Club de la Amistad', 'Treasure Island',
#        'The Human Body', 'Minecraft: The Dragon',
#        'The Christmasaurus and the Naughty List', 'Das Exil',
#        'El Cerdito de Navidad [The Christmas Pig]',
#        'Big Change for Stuart', 'The Imagination Box: Beyond Infinity',
#        'Camp Daze', 'Vaiana', 'Myth of the Rain Forest Monster',
#        'Little Badman and the Time-travelling Teacher of Doom',
#        'The Great Dream Robbery', 'Barbie - Superprincesa',
#        'Barbie - El campamento de princesas', 'Barbie - Dreamtopia',
#        'Among Us Book - Red Diary', 'Were Going to Find the Monster',
#        'Ut i det vilda', 'The Imagination Box: A Mind of Its Own',
#        "Dungeons & Dragons: The Mad Mage's Academy",
#        'Scary Stories for Young Foxes: The City', 'Med kunglig stmpel',
#        'Bolt', 'The Tenth Son', 'Escape from Falaise', 'The Jungle Book',
#        'PJ Masks - 3-Minuten-Gutenachtgeschichten',
#        'Opapi-Opapa - Volle Kraft voraus!',
#        'Opapi-Opapa - Besuch von den Krawaffels',
#        'Als Papa auf einen Knopf drckte und wir fast von einem Dino gefressen wurden',
#        'Spidey og hans fantastiske venner',
#        'Phantom Stallion: Blue Wings',
#        'Super Pigiamini - Storie della buonanotte da 5 minuti',
#        'Lost Island', 'The Boy Who Hatched Monsters',
#        'The Magic Ocean Slide & The Giant Conker', 'Krieg der Fluten',
#        'The Secret of Splint Hall', 'Tschakka! - Freunde in Sicht',
#        'El candidato novato', 'The Call of the Silver Wibbler',
#        'Frankie Best Hates Quests', 'Trapped in the Overworld',
#        'The Boy Who Biked the World: On the Road to Africa',
#        'The 143-Storey Treehouse', 'Unicorn Academy: Isla and Buttercup',
#        "Herobrine's War", 'Small Change for Stuart', 'The Extreme',
#        "Alain l'alien", 'Wingfeather Tales',
#        'Spider-Man gegen Sandman / Spider-Man und die Marvels',
#        'Swamp Sting!', 'Poison Jungle', '39 Clues: Cahills vs. Vespers',
#        'Adventure Time - Too Many Bananas & Other Stories', 'Blue Moon',
#        "The Last Kids on Earth: June's Wild Flight",
#        'Captain Underpants and the Terrifying Return of Tippy Tinkletrousers',
#        'Mermaids of the Deep Blue Sea', 'Flying Ninja!',
#        'Fortress of the Stone Dragon',
#        'Zoey and Sassafras: The Pod and the Bog',
#        'PJ Masks - Hroes en Pijamas - Los lobeznos!',
#        'PJ Masks - Potncia PJ!', 'PJ Masks - Preparats per a lacci!',
#        'Mortel un jour, Mortel toujours!',
#        'Pyjamasankarit - 3 minuutin iltasatuja',
#        'PJ Masks - Vet aqu en Robot PJ!', 'PJ Masks - PJ Robot',
#        'Le gant de pierre', 'Pyjamasankarit - Nousu taikavuorelle',
#        'PJ Masks - Hroes en Pijamas - Catboy y el gran rescate de la torta de cumpleaos',
#        'Tijl en de tijdbom', 'Genius Camp', 'The Talisman of Lostland',
#        'Star Wars: The High Republic: A Test of Courage',
#        'The Secret Explorers and the Plant Poachers', 'The Red Slippers',
#        'Captain Underpants and the Preposterous Plight of the Purple Potty People',
#        "The Magician's Secret", 'The Case of the Bizarre Bouquets',
#        'Shockwave', 'The Phantom of Nantucket', 'The Swamp Robber',
#        'The Magic Finger', 'The Adventures of Captain Underpants',
#        'Secret at Mystic Lake', 'Fight for Dusty Divot',
#        'I Survived the Sinking of the Titanic, 1912',
#        'Showdown at Widow Creek', 'Case of the Missing Marquess',
#        'Nightshade', 'Mystery of the Phantom Heist',
#        "Mousse  l'cole des pirates", 'Riding Home Through Asia',
#        'The Boy Who Biked the World: Riding the Americas',
#        'El Misterio de la Montaa Azul',
#        'Grand-mre Sucre et Grand-pre Chocolat', 'La chambre des pirates',
#        'Tapator le dinosaure', 'Une pomme pour deux', 'Romo et Biquette',
#        'Bienvenue chez Vampirette', 'Toc, toc ! Qui est l ?',
#        'Un poisson nomm Marina', 'Du lait pour mon chat',
#        'Le grand voyage de Nils Holgersson',
#        'Qui veut jouer avec Renard ?', 'Le petit roi Moi Moi Moi !',
#        'Pas de lunettes sur ma tte !',
#        'Penny Berry y la batalla de Cairngorms',
#        'Marvel - Tillbaka till urtiden',
#        'Thor - Begynnelsen - Fin Fang Fooms uppgng och fall!',
#        'Black Panther - Kampen om Wakanda',
#        'Ali Baba and the Forty Thieves',
#        'La fe Fifolette a cass sa baguette', "Le gros chagrin d'Edgar",
#        'Qui a vol le diamant de Big Jack ?',
#        'La fe Fifolette dclenche des temptes',
#        'Le petit chevalier courageux', 'La banda della zuppa di piselli',
#        'Princesse Sarah', "Le voleur d'Edith",
#        'Veinte mil leguas de viaje submarino', 'Historias de miedo',
#        'Misterio en las vas',
#        'Sofabanditen oder Die verrckte Befreiung der Hhner',
#        'En el infierno', 'PJ Masks: Carrera en la Montaa Misteriosa',
#        'DC Jones and Adventure Command International 2',
#        'Robatori a la platja', 'Barbie - Els superpoders de princesa',
#        'Barbie - Pop per a princeses', 'Limamerirosvojen jljill',
#        'Barbie - Buscant les gossetes', 'Barbie - La porta secreta',
#        'Die Hamsterdam-Verschwrung',
#        'Els Barrufets - Histries dels barrufets',
#        'La maison qui ne dormait jamais',
#        'Els Barrufets - Histries de 3 minuts', 'Wolvenhart',
#        'Circus Maximus Rivals on the Track',
#        'PJ Masks - Cursa cap a la Muntanya Misteriosa',
#        "Super Pigiamini - Pronti all'azione!",
#        'PJ Masks - En Gatnoi i el gran rescat del pasts daniversari',
#        'Anatole Latuile fait son cinma', 'The Midnight Thief',
#        'Suche nach der verborgenen Quelle',
#        'El misterio del coleccionista de tazos',
#        'Los Pitufos - Historias de Pitufos', 'Dando la nota',
#        'Los Pitufos - Historias de 3 minutos', 'Vacaciones, no gracias',
#        "A Baker's Guide to Robber Pie", 'The Counterclockwise Heart',
#        'Knight Sir Louis and the Dragon of Doooooom!',
#        'Ferien auf Saltkrokan - Pelle findet einen Wunschstein',
#        'Bob el Constructor - Perros y gatos', 'The Secret of Haven Point',
#        'The Mouse Watch in Space', 'Freewater', 'The Book of Stolen Time',
#        'The Experiment', 'The Exposed',
#        'Big Sky Mountain: The Forest Wolves', "The Golem's Eye",
#        'The Count of Monte Cristo', 'Howl of the Wind Dragon', 'Pony',
#        'World Champions!', 'Minecraft: Mob Squad', 'The Threat',
#        "The Tiger's Nest", 'The Beekeeper Mystery',
#        'The Shattered Castle',
#        'Peanut Jones and the Illustrated City: from the creator of Draw with Rob',
#        'Sparrow Rising', 'Shadowghast', 'The Beatryce Prophecy',
#        'Brother Wulf', 'Rise of the World Eater', 'The Unadoptables',
#        "Barbie - Equip d'espies", 'The Mapmakers',
#        'The Professor and the Puzzle', 'The Paper Dolls',
#        'The 39 Clues, Book 5', 'Scorpia', 'A Con Artist in Paris',
#        'Tunnel of Bones', 'The 13-Storey Treehouse',
#        'The 39 Clues, Book 9', 'Kid Normal and the Rogue Heroes',
#        'Shine of the Silver Dragon', 'Treasure of the Gold Dragon',
#        'The 1,000-Year-Old Boy', 'Strangers on a Train', 'Darkstalker',
#        'Peter Rabbit 2', 'Dinosaurs Before Dark', 'The Outcast',
#        'Wave of the Sea Dragon', 'Escape from Aurora', 'The Monkey King',
#        'Getting Grannys Glasses', 'Where the Red Fern Grows',
#        'The 39 Clues, Book 10', 'Future of the Time Dragon',
#        'Field Trip Fiasco',
#        'Captain Underpants and the Big, Bad Battle of the Bionic Booger Boy, Part 2',
#        'The Carpet People', 'Clash at Fatal Fields',
#        'Deception on the Set', 'The Tale of Tom Kitten',
#        '20.000 Leguas de viaje submarino [20,000 Leagues Under the Sea]',
#        'Dungeons & Detectives', 'A Script for Danger',
#        'The Battle of Bayport', 'Capitaine',
#        'Iron Man - Rymdfantomernas invasion!',
#        'City of Ghosts - Im Reich der vergessenen Geister',
#        'Ariana y Arcana', 'La aventura de Amunet', 'Amigos de verdad',
#        'Pan, nuestro hermano del bosque',
#        'PJ Masks - Vet aqu els Mini Llops!', 'Ufo in Seenot',
#        'The Chromatics Camp at The Musical Mountain',
#        'Attack of the Shadow-Crafters', '   ',
#        'Ritter Klapperschwert und die groe Freundschaft',
#        'H@Ck - Het instituut', '  ', 'Gupi Funio', 'Un problema con alas',
#        'Die Meckerpause', 'El Club de la Luna Llena',
#        'Spider-Man - En samling berttelser',
#        'Enigma en el puente del naranjo',
#        'Penny Berry y la cripta de los olvidados',
#        'Penny Berry y la pcima mgica', 'La casa embrujada',
#        'Lady och Lufsen', '   !',
#        'James und die fischige Fracht / Hiro und die widerspenstigen Waggons',
#        'Avengers - God Jul!', 'En busca del seor T',
#        'Avengers - TRE spektakulra ventyr!',
#        'Captain America och morgondagens arm!', 'Superhjltarna', ' ',
#        'Spider-Man - Kortslutning', 'The Far-Finding Ring',
#        'When the War Came Home', 'Modig - Meridas nskan',
#        'Il viaggio leggendario di Erick e Dominick',
#        'Doctor Strange - Vejen til viden',
#        'Pyjamasheltene - Kattedreng og den store fdselsdagskageredning',
#        'Pyjamasheltene redder dagen!', 'The Great Zombie Invasion',
#        'The Buried Crown', 'The Wishing Star & The North Pole Picnic',
#        'Cora y los Corales', 'Fortidens skygger', "Racconti dall'India",
#        'Piratbarn har ikke lngere brug for sin sut', 'Alpaca My Bags',
#        "L'le du mage", 'Speedy', 'The Santa List',
#        'Paradise Pirates retten Captain Scratch', 'Loca por Hugo',
#        'Ninja Niller - Blodets Bnd: Del 4',
#        'Marvel - Den stora sagosamlingen', 'Bilar 3',
#        'Falcon - Fkta eller flyga', 'Barbie - Aventura en el espacio',
#        'El misterio de la virgulina inmortal', 'Ein Mdchen namens Owl',
#        'Antigua de Fortune of the High Seas', 'The Smidgens',
#        "Revoluci a la botiga d'animals", 'Te regalo el mundo',
#        'Et regalo el mn', 'Revolucin en la tienda de animales',
#        'Ribblestrop Forever!', ' ,   ', '     ', '', '  .      ',
#        '  .    ()', '  .     7-10 ', ', !', ' .   ', 'Das Feuer',
#        'Familie Maulwurf auf der Flucht',
#        'Die Spiegelspringer - Im Bann der Geschichten', 'The Attack',
#        'Symbiosis', 'Stella und der Mondscheinvogel', 'Saids Schicksale',
#        'Surviving Jamestown', 'Slvese quien pueda!',
#        'Cuentos locos para nios inteligentes',
#        'Wednesday: The Forest of Secrets',
#        'Ronan Boyle into the Strangeplace', 'Girl Giant and the Jade War',
#        'Kidnapped Colt', 'Cmo como', 'Der Zeitring',
#        'Ivy & Bean Bound to Be Bad (Book 5)',
#        'Ivy & Bean Take Care of the Babysitter (Book 4)',
#        'Ivy & Bean Break the Fossil Record (Book 3)', 'Moonrise',
#        'Vega Jane and the End of Time', 'The Suspicion', 'The Pretender',
#        'Hide and Geek', 'Sunlight on the Snow Leopard',
#        'Me and My Little Brain', 'Coraline', 'The Van Gogh Deception',
#        'Moon Rising', 'Abenteuer-Ferien bei Opa Balduin',
#        'Hello Kitty - La aventura animal',
#        'Hello Kitty - La estrella de televisin',
#        'Hello Kitty - Vacaciones en la playa',
#        'Hello Kitty - El misterio de la madalena',
#        'Hello Kitty - La bsqueda del tesoro',
#        'Hello Kitty - Sesin de belleza', 'Ravenburcht', 'De Utrolige 2',
#        'Ariadna y la luna Lunera', "L'Ariadna i la lluna Pruna",
#        'La Mariona i la Menjanits',
#        'Captain Underpants and the Attack of the Talking Toilets',
#        'Holes', 'The 39 Clues, Book 1',
#        'The Princess in Black, Books 1-3',
#        'Pyjamasankarit - Tss tulee Pyjamarobotti!',
#        'Pyjamasankarit - Polkuvoimaa!', 'PJ Masks - Sigues un heroi!',
#        'Pyjamasankarit - Ollaan sankareita',
#        'Pyjamasankarit - Tss tulee susijengi',
#        'Pyjamasankarit - Kolli ja synttrikakun pelastusoperaatio',
#        'Fly High Crew: The Green Glow',
#        'Vitello va a un cumpleaos de nias',
#        'Vitello compra un maravilloso regalo de Navidad',
#        'Vitello salva el mundo',
#        'Vitello construye un Abominable Hombre de las Nieves',
#        'Vitello hace una obra de caridad', 'Vitello pide un deseo',
#        'Vitello pide un montn de chuches',
#        'Barbie - En busca de las cachorritas',
#        'El misterio del ladrn narizotas', 'Willy y el arenque asesino',
#        'Pasado por auga', 'PJ Masks - Los nios lobunos!',
#        'Nomie Hollemechette', 'Il primo disastroso libro di Matt',
#        'Franoise la mauvaise tte', 'Sotto la stella del lupo',
#        'Los Rescatadores Mgicos y la tostadora de los deseos',
#        'Superhjltar p ventyr - Spider-Man fr superhjlp!',
#        'Atrapados en el monte Olimpo',
#        'The Worst Class in the World Dares You!',
#        'Der Ruf des Mondsteins', 'Pizza Power',
#        "The Case of the Smuggler's Curse", 'The Lock-Eater',
#        'Brave New Pond', 'The Box-Car Children', 'Wild River',
#        'The Wild Robot: Booktrack Edition', 'Skeleton Key',
#        'Demon Dentist', 'Hidden Pictures', 'The Lost Continent',
#        'Unicorn Academy: Ariana and Whisper', 'A Long Walk to Water',
#        'Talons of Power', 'Bound for Danger',
#        'Captain Underpants and the Big, Bad Battle of the Bionic Booger Boy, Part 1: The Night of the Nasty Nostril Nuggets',
#        'Hello Kitty - El da de la boda',
#        'Hello Kitty - La excursin escolar',
#        'Hello Kitty - La princesa del pop', 'Hetoneindigeverhaal',
#        'Mariona y Comenoches', 'Thomas@geraamte.net (Afrikaans Edition)',
#        'Warhammer Adventures: Battle for the Soulspring',
#        'Warhammer Adventures: Fortress of Ghosts', 'Black Powder',
#        'Le Mystre du train de la nuit', 'Drachenalarm', 'Superjuffie!',
#        'Begyndelsen - Storm i sigte',
#        '101 Dalmatinere - Begyndelsen - Anitas hemmelige hvalp',
#        'Zote rkawice Arachne!', 'Die Traumwelt', 'Swashbuckler',
#        'Paddington, le roman du film', 'Get a Hold of Your Elf!',
#        'Niemals den roten Knopf drcken oder die Dinos drehen durch',
#        'Le fabuloup gteau de Gros-Louis', "Loup et ses amis. L'intgrale",
#        "L'anniversaire de Louve", "Edmond le dragon et l'incendie",
#        'La machine  vux de Valentin',
#        'La drle de maladie de Demoiselle Yti', 'Le secret de Joshua',
#        'Alfred et le monstre de la fort', 'Comenoches',
#        'Mrtel und Maus wollen hoch hinaus', 'Un viaje ms all de Sodor',
#        'El prisionero de la fantasa', 'Das Hotel der Wnsche',
#        'Der Verrat', 'Das verbotene Turnier',
#        '    [Deniska at the North Pole]', 'Lampie',
#        'Spider-Man rettet Weihnachten / Spider-Man und seine Insektenfreunde',
#        'Otto der Flaschengeist', 'Peter Pan',
#        "L'Ogre qui aimait les champignons", 'Une mission parfume!',
#        'De prcieux passagers', 'La Grande Course', 'Un concert enflamm',
#        'Thursdays with the Crown',
#        'Marvel Spider-Man - 5-Min-Geschichten',
#        'Un super match de football', 'Un super chien de sauvetage',
#        'The Spitfang Lizard', 'Little Horror', 'Un sauvetage magique',
#        'Un cheval  sauver', 'Cano  la Drive!', 'Disparition au Zoo!',
#        'Concours en pril', 'La Tempte de Dhves',
#        'Im Bannkreis des Schwurs Teil 2',
#        'Im Bannkreis des Schwurs Teil 1', 'La Route du courage',
#        'Bazar chez les locomotives', 'Le Mystre de la montagne bleue',
#        'Le Roi du chemin de fer', 'Que le meilleur gagne !',
#        'Los Atrevidos', 'Luca y Ema dan un paseo en bicicleta',
#        'Luca y Ema celebran sus cumpleaos',
#        'Luca recibe un cachorro de regalo', 'Gulliver XXI', 'Midnatt',
#        'Den mrka floden', 'Visionen', 'Blood Captain',
#        'Zeinumb. Parque de atracciones', 'El mejor regalo del mundo',
#        'The Hunt for the Five', 'Un amico a sorpresa',
#        'Eine dunkle Verschwrung', 'Alarm im Park',
#        'Los vestidos de Pancheta', 'Aventures sur le continent',
#        'Tafiti und der groe Zauberer', 'Silas and the Marvellous Misfits',
#        'Cheeky and Charlemagne', 'El Agujero Negro [The Black Hole]',
#        'La Lgende du trsor perdu de Chicalor',
#        'Los rescatadores mgicos en las magiolimpiadas',
#        'Los rescatadores mgicos en el bosque de los gamusinos',
#        'El ladrn de la fantasa', 'Freddy vs. School', 'City of Rust',
#        'Polly Pecorino', 'Mambr Perdi la Guerra [Mambr Lost the War]',
#        'Dragon Skin', 'Eld och is', 'Crowfall',
#        'Die Muskeltiere und die groe Kseverschwrung',
#        'Tom und die Schildkrtenschmuggler',
#        'Travesuritis aguda [Acute Travesuritis]', 'Hola, puedo ayudar?',
#        'El hombre que perdi su imagen', 'Todo se rompe',
#        'The Ice Whisperers', 'Malicia en el pas de las fechoras',
#        'Wilma Walnuss und das kleine Baumhotel',
#        "Brother Wulf: Wulf's Bane", 'The Goldsmith and the Master Thief',
#        'Bin Boy', 'Un da en casa', 'El guerrero fantasma',
#        'La leyenda del wendigo', 'The Raven Heir',
#        'Extra Weird Creatures',
#        'I Survived the Galveston Hurricane, 1900',
#        "The Week at World's End", 'The Imagination Box',
#        'Nehmt euch in Acht!', "Allez, les verts! [Let's Go Green!]",
#        'The Monsters of Rookhaven', 'Les Histoires pour petites oreilles',
#        'DJ Funkyfoot: Give Cheese a Chance!',
#        'Les aventures de Sven le terrible. Pas de princesse pour les pirates. [The Adventures of Sven the Terrible. No Princess for Pirates.]',
#        'Dungeons & Dragons: Big Trouble',
#        'Dungeons & Dragons: Escape from Castle Ravenloft',
#        'Dungeons & Dragons: Escape the Underdark',
#        'Dungeons & Dragons: To Catch a Thief', 'Uno skate per due',
#        'PIN-0-TXO vol tenir amics', 'PIN-0-TXO vol tenir nima',
#        'Noticias frescas', 'Una boda desmadrada',
#        'Zack Galaxy: misin secreta', 'El rockero',
#        'Un poco de pasta, basta', 'Los mayores estn locos, locos, locos',
#        'Hijos de Asgard', 'La estrellita de mar', 'Brisca',
#        'La nia que siempre deca no', 'El nio que era muy hombre',
#        'El nio que tena mucho hermano', 'Slo soy una nia', 'El brujo No',
#        'El perro del seor Gris Marengo', 'Zorro blanco',
#        'Im kleinen wilden Schnergenland',
#        'Komm flieg mit uns ins Abenteuer!', 'Spuren im Wald',
#        'Ein rtselhafter Unfall',
#        'Rupert prsentiert - Ein echt wildes Abenteuer', 'Luftpiraten',
#        'Luis und Lena - Der Zwerg des Zorns', 'Ozean in Flammen',
#        'Rille - Ein Dschungel voller Abenteuer!',
#        "mo-J : Attention  l'agent Paul [Emo-J: Watch Out for Agent Paul]",
#        'Dungeons & Dragons: Into the Jungle', 'Egg Marks the Spot',
#        'Tabitha Plimtock and the Edge of the World', 'Always',
#        'The Puffin Portal', 'The Grunts on the Run',
#        'Utterly Dark and the Face of the Deep',
#        'The Peculiar Tale of the Tentacle Boy', 'A Mouse Called Miika',
#        'Nell and the Cave Bear', 'Oupa Zombie', 'The Other Side of Luck',
#        'Heartbreak Bronco', 'Rain Dance', 'Untamed', 'Red Feather Filly',
#        'Gift Horse', "Vega Jane and the Rebels' Revolt",
#        'The Boy with Wings', 'Tuesday: The Curse of the Blue Spots',
#        'Monday: Into the Cave of Thieves', 'City of Thieves', 'Concealed',
#        "Ricky Ricotta's Mighty Robot vs. the Naughty Nightcrawlers from Neptune",
#        'A Trick of Time', 'Oddity', 'Gladys the Magic Chicken',
#        'Me vs. the Multiverse: Enough About Me', 'Share Your Rainbow',
#        'The Worries: Jaz and the New Baby', 'The Aeneid',
#        'Nuclear Distraction', 'Beauty and the Dreaded Sea Beast',
#        'Double Trouble', 'La fe Fifolette et le gteau Bonbon',
#        'Joyeux anniversaire, Princesse Mlie',
#        'Il faut sauver la princesse Blanche !', "Le cadeau d'Amazonie",
#        'Thomas y sus amigos - Misterio en las vas',
#        'Bob y sus amigos - Perros y gatos',
#        'Thomas y sus amigos - La gran carrera',
#        'Thomas y sus amigos - El rey de las vas',
#        'Thomas y sus amigos - El Misterio de la Montaa Azul',
#        'Thomas y sus amigos - Historias de miedo',
#        'Bob y sus amigos - La casa del rbol de Saffi',
#        'Thomas y sus amigos - Carrera hacia el castillo de Callan',
#        'Thomas y sus amigos - Da de los Disel',
#        'Bob y sus amigos - El dinoparque',
#        'Qui a vol le deuxime but? [Who Stole Second Base?]',
#        'Thomas@sms.net (Afrikaans Edition)',
#        'Thomas@rock-ster.net (Afrikaans Edition)',
#        'Thomas@skaduwee.net (Afrikaans Edition)',
#        'Penny Berry y el rbol de oro de Shangri-La',
#        'Le trs chanceux monsieur Confetti',
#        "C'est la petite bte qui monte", 'Li Le La', 'Superhjltarna 2',
#        'Bamse ja noita-akan tytr', 'Escape Room',
#        "Les mmoires d'un ne de la Comtesse de Sgur",
#        'Les deux nigauds de la Comtesse de Sgur',
#        'Phantom Stallion: Secret Star',
#        'Petit-Gaulois veut des moustaches',
#        'Les vacances de la Comtesse de Sgur',
#        'Les petites filles modles de la Comtesse de Sgur',
#        'Thor - Helten fra Asgrd', '1er zavril sur la plante Zars',
#        'Les malheurs de Sophie de la Comtesse de Sgur',
#        "L'auberge de l'Ange-gardien de la Comtesse de Sgur",
#        'Le gnral Dourakine de la Comtesse de Sgur',
#        'Un bon petit diable de la Comtesse de Sgur',
#        "La Montagne d'bne [The Ebony Mountain]",
#        'Thomas@vrees.net (Afrikaans Edition)',
#        'Thomas y sus amigos - Que gane el mejor!',
#        'Spider-Man og Iron Man - Md dine helte!', 'The Balloon Thief',
#        'Getting to the Bottom of Global Warming',
#        'Les 12 Coffrets de Goradenn le Fol', 'Gschichte vom Schnff',
#        'Penny Berry y el anillo de Shazzan',
#        'Bamse ja maailman seitsemn uutta ihmett', 'Vi Spy 2',
#        'PJ Masks - Catboy bjargar afmliskkunni',
#        'PJ Masks - Gatuno y la encogedora',
#        'PJ Masks: Hroes en Pijamas - All vamos!',
#        'PJ Masks: Hroes en Pijamas - Catboy y la mquina encogedora',
#        'PJ Masks: Hroes en Pijamas - Robot en pijama',
#        'PJ Masks: Hroes en Pijamas - Cuentos de tres minutos para dormir',
#        'PJ Masks: Hroes en Pijamas - Hroes y heronas!',
#        'PJ Masks - Carrera en la Montaa Misteriosa',
#        'PJ Masks: Hroes en Pijamas - Pedaleando a toda velocidad!',
#        'PJ Masks - Cuentos para dormir de tres minutos',
#        'PJ Masks - Contes de 3 minuts per anar a dormir',
#        'PJ Masks - En Gatnoi i lEncongidor', 'Pidamersi - Bd bohaterem!',
#        'Mauritz findet das Glck', 'PIN-8 quiere tener superfuerza',
#        'Tafiti und die Expedition zum Halbmondsee',
#        'Le vaillant petit tailleur', 'Les chevaliers',
#        'Maya et le volcan Pipicaca', 'Merci pour les crpes, Jasmin !',
#        'Una tormenta de deseos', "7 histoires d'enqutes !",
#        'Le cakosaure de Nino Dino', 'Le doudou du loup', 'Les pompiers',
#        'Los Banddez', "Fiabe d'incantesimi", 'Susanna e il soldato',
#        'Le manchot qui voulait avoir chaud', 'Le petit pompier',
#        "Zouk  l'cole des sorciers", 'Der Wildtter', 'Graffiti & Cie',
#        'Carrera hacia el castillo de Callan', 'La gran carrera',
#        'Le petit empereur de Chine', 'La ermita de los espritus',
#        'A Thunder of Monsters', 'Fabula - Das Portal der dreizehn Reiche',
#        'Racing Storm Mountain', 'Da de los Disel',
#        'La leyenda del tesoro perdido', 'Grimorgas Erwachen',
#        'Der wahrlich wildbewegte Flug im Luftschiff',
#        'El ladrn de salchichn', 'Barbie - Equipo de espas',
#        'Misterio en el campo de golf',
#        'Sea Monsters - Ungeheuer weckt man nicht',
#        'El misterio de los ocho bebs', 'Que gane el mejor!',
#        'Juan y el teatro de la lluvia', 'PJ Masks - Pedaleando a tope!',
#        'PJ Masks - Gatuno y el gran rescate de la tarta de cumpleaos',
#        'Aufbruch ins Land der Tierflsterer',
#        'Caspar und die Trne des Phnix',
#        'Minna Melone - Wundersame Geschichten aus dem Wahrlichwald',
#        'Atemlos', 'El misterio de la gata maga', 'Ein gefhrlicher Pakt',
#        'The House in the Woods', 'The Ghost of Scarletbeard',
#        'Mort the Meek and the Monstrous Quest',
#        'Ambrose Follows His Nose', 'The Reunion',
#        'Noni and the Great Chawwwklit Mystery',
#        'Adventures in Super Happy Magic Forest',
#        'The Secret Explorers and the Moon Mission', 'The Last Firefox',
#        'The Sickness', 'Thursday: War of the Waterslides',
#        "The Gas-Fitters' Ball", "Thunderbolt's Waxwork",
#        'Children of the Flying City',
#        'A to Z Mysteries Super Edition 10: Colossal Fossil',
#        'Minecraft: Mob Squad: Never Say Nether',
#        'The Case of the Curious Scouts', 'Firefly',
#        'Hollywood vs. the Galaxy',
#        'A to Z Mysteries Super Edition 2: Mayflower Treasure Hunt',
#        'Map of Flames', 'Mystery of the Midnight Rider',
#        'The Smoke Thieves', 'The Haunting on Heliotrope Lane',
#        'The Stolen Show', 'Minecraft: The Crash', 'Scorpia Rising',
#        'Song of the Poison Dragon', "Three Tales of My Father's Dragon",
#        'Treasure Hunters', 'Star Wars: The Last Jedi',
#        'Captain Underpants and the Perilous Plot of Professor Poopypants',
#        'Captain Underpants and the Invasion of the Incredibly Naughty Cafeteria Ladies from Outer Space',
#        'Famous Mistakes', 'Minecraft: The Lost Journals',
#        "The Witch's Boy", 'Whatever After Collection, Books 1-3',
#        'The Hive Queen', 'Mac Saves the World',
#        'My Parents Cancelled My Birthday', 'Nightfall',
#        'The Curse of the Ancient Emerald',
#        'The Last Kids on Earth and the Skeleton Road',
#        'Doctor Who: Thirteen Doctors 13 Stories',
#        "The Gray Hunter's Revenge", 'Magisterium: The Iron Trial',
#        "Mr. Lemoncello's Great Library Race", 'The Fourth Closet',
#        'The Magic School Bus Inside the Human Body',
#        'Power of the Fire Dragon', 'School for Crooks',
#        'Magisterium: The Golden Tower', 'The Troll', 'Lockwood & Co.',
#        'Never Fade', '100 Cupboards', 'Ben Braver and the Vortex of Doom',
#        'The Magic Misfits: The Second Story', 'The Election Day Dilemma',
#        "Tiger's Curse", 'Just William - More William',
#        'Public Enemy Number Two', 'Mercy Watson #3',
#        'A to Z Mysteries: The Zombie Zone', 'Afternoon on the Amazon',
#        'Troll Mountain', 'The Magic Misfits: The Fourth Suit',
#        "Princess Ellie's Holiday Adventure", 'Wizard for Hire',
#        'Hour of the Olympics', 'Princess Ellie to the Rescue',
#        "Father Christmas's Fake Beard", 'One Stormy Day',
#        'LEGO Ninjago: Brick Adventures #1: Brother/Sister Squad',
#        'Infinity Ring, Book 3: The Trap Door', 'The Emperor of Nihon-Ja',
#        'The Comic Book Mystery',
#        "Nick and Tesla's High-Voltage Danger Lab",
#        'The Penderwicks on Gardam Street', 'The Midnight Mystery',
#        'The Missing Prince', 'The Sound of Danger', 'Mac Undercover',
#        'Adventures from the Land of Stories Boxed Set',
#        'El Ickabog (Spanish Edition)', 'The Star of Kazan',
#        'The Sea Turtle Mystery', 'Black Beauty', 'Shoe Wars',
#        'Fablehaven, Book 2', 'Good Dog', 'Winter Turning',
#        'The 39 Clues, Book 7', 'Trust No One',
#        'The Quest for the Artifacts', 'The 117-Storey Treehouse',
#        'The Mighty Odds', 'Hansel and Gretel', 'The 39 Clues: Flashpoint',
#        'Earthquake', 'Stolen Identity',
#        'Dr. Fell and the Playground of Doom', 'The 39 Clues', 'Rostig!',
#        'Il principe e il leone', 'Child I', 'Die neue Zeit',
#        'The Tzars Curious Runaways', 'The Dead World of Lanthorne Ghules',
#        'PIN-0-TXO vol tenir superfora', 'Zack Galaxy: persecucin total',
#        'Zack Galaxy: una aventura intergalctica', 'Relatos fantsticos',
#        'El nio que siempre deca s', 'Menuda cabeza!', 'Quin cap!',
#        'El Bloque', 'Eine Freundschaft aus Wind und Magie',
#        'Alarm in der Delfin-Lagune', 'Tschakka! - Huhn voraus',
#        "George's Cosmic Treasure Hunt",
#        'Magisterium: The Copper Gauntlet',
#        'The Penderwicks at Point Mouette', 'Stormspeaker',
#        'Evie and the Animals', 'The Boy Who Dreamed of Dragons',
#        'The Guggenheim Mystery', 'George and the Blue Moon',
#        'Escaping Peril', 'The Case of the Deadly Ha-Ha Game',
#        'Rise and Fall', 'The Great Paper Caper',
#        'Broken: The Vampires, the Magic Stones, and the Cursed Child',
#        'Caterflies and Ice', 'George and the Unbreakable Code',
#        'George and the Ship of Time', 'Shadows at Predator Reef',
#        "Charlie Cook's Favourite Book",
#        'Klawde: Evil Alien Warlord Cat, Book 1', 'Ringo & the Yogi',
#        'The Miraculous Journey of Edward Tulane',
#        'Roar of the Thunder Dragon', 'The Mercy Watson Collection',
#        'Narwhal on a Sunny Night',
#        "The Jungle Book (BBC Children's Classics)", 'The Drowned Vault',
#        'The Green Ember', 'The Burning Tide', 'My Side of the Mountain',
#        'Magisterium: The Silver Mask', 'Evie in the Jungle',
#        'Battle for Loot Lake: An Unofficial Fortnite Adventure Novel',
#        'Midnight for Charlie Bone', 'Midnight on the Moon',
#        "Erak's Ransom"], dtype=object)

# %%
df1[df1["name"].str.encode('ascii', 'ignore').isnull()]
# Out:
# Empty DataFrame
# Columns: [name, author, narrator, time, releasedate, language, price, star_rating, rating]
# Index: []

# %%
book_version_pattern = re.compile(r"(\s#?\d+\s?(&|and)?\s?#?(\d+)?)|(:?,?\sBooks?\s\d+\s?-?(\d+)?)")
nan_books_version = df1[df1["name"].str.replace(book_version_pattern, "").isnull()]

# %%
# remove the versions from the "name"
book_version_pattern = re.compile(r"(\s#?\d+\s?(&|and)?\s?#?(\d+)?)|(:?,?\sBooks?\s\d+\s?-?(\d+)?)")
df1["name"] = df1["name"].str.replace(book_version_pattern, "").copy()

# %%
# split those values which have 2 or more author or narrator
df1["author"] = df1["author"].apply(lambda x: x.split(",") if "," in x else [x])
df1["narrator"] = df1["narrator"].apply(lambda x: x if pd.isna(x) else x.split(",") if "," in x else [x])

# %%
df1.isnull().sum()
# Out:
# name           0
# author         0
# narrator       0
# time           0
# releasedate    0
# language       0
# price          0
# star_rating    0
# rating         0
# dtype: int64

# %%
# remove the more informations from the "author" col because most of the values 
# has no such info. Also, while modifying this col before, some blank strings
# (e.g. record no. 77) created. That strings will be removed here. Also, here
# will separate the first name and the last names. Previously those are not
# separated with a white space.

def separate_first_last_name(text):
    # create the regex pattern
    pattern = re.compile(r"[A-Z]+[a-z]+")
    # join the first & last name with a white space and return it
    return " ".join(re.findall(pattern, text))

def remove_more_info(text_list: list):
    if type(text_list) != list and pd.isna(text_list):
        return text_list

    # create the re pattern to remove the more info
    pattern = re.compile(r"-\w+")
    result = []

    # loop through the each values
    for item in text_list:
        # remove the empty string
        if len(item) != 0:
            # remove the more info
            re_result = re.sub(pattern, "", item)
            # separate the first and the last name
            result.append(separate_first_last_name(re_result))
    
    # if the result list is empty, then return NaN or return as it is
    return np.nan if len(result) <= 0 else result

# %%
df1["author"]   = df1["author"].apply(lambda x: remove_more_info(x)).copy()
df1["narrator"] = df1["narrator"].apply(lambda x: remove_more_info(x)).copy()

# %%
df1.head()
# Out:
#                                  name              author           narrator  \
# 0                    Geronimo Stilton  [Geronimo Stilton]      [Bill Lobely]
# 1                    The Burning Maze      [Rick Riordan]   [Robbie Daymond]
# 2                        The Deep End       [Jeff Kinney]      [Dan Russell]
# 3                Daughter of the Deep      [Rick Riordan]  [Soneela Nankani]
# 4  The Lightning Thief: Percy Jackson      [Rick Riordan]  [Jesse Bernstein]
#
#    time releasedate language  price  star_rating  rating
# 0   140  2008-08-04  english  468.0          5.0      34
# 1   788  2018-05-01  english  820.0          4.5      41
# 2   123  2020-11-06  english  410.0          4.5      38
# 3   676  2021-10-05  english  615.0          4.5      12
# 4   600  2010-01-13  english  820.0          4.5     181

# %%
df1.to_pickle("audiable_cleaned.pickle")

# %%
pd.read_pickle("audiable_cleaned.pickle").head()
# Out:
#                                  name              author           narrator  \
# 0                    Geronimo Stilton  [Geronimo Stilton]      [Bill Lobely]
# 1                    The Burning Maze      [Rick Riordan]   [Robbie Daymond]
# 2                        The Deep End       [Jeff Kinney]      [Dan Russell]
# 3                Daughter of the Deep      [Rick Riordan]  [Soneela Nankani]
# 4  The Lightning Thief: Percy Jackson      [Rick Riordan]  [Jesse Bernstein]
#
#    time releasedate language  price  star_rating  rating
# 0   140  2008-08-04  english  468.0          5.0      34
# 1   788  2018-05-01  english  820.0          4.5      41
# 2   123  2020-11-06  english  410.0          4.5      38
# 3   676  2021-10-05  english  615.0          4.5      12
# 4   600  2010-01-13  english  820.0          4.5     181
